# %%
import pandas as pd

# %%
data = pd.read_json("plant_data.json")
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_json("plant_data.json")
#       2 data
#
# File ~/Documents/group_project_week1/Group-Project-Advanced-Data-Week-5/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~/Documents/group_project_week1/Group-Project-Advanced-Data-Week-5/.venv/lib/python3.13/site-packages/pandas/io/json/_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# ...
